# %%
import sys
if 'google.colab' in sys.modules:
    # !uv pip install --system --pre ngsolve

# %% [markdown]
# # Gallery
#
# * 3D block with holes
# * twisted beam
# * meta-material
# * eigenvalues of disc
# * elasto-dynamics
