# %% [markdown]
# # Implementing Finite Elements in NGSolve
#
# ## i-FEM Lecture notes:
#
#   - [standard low order fem](https://jschoeberl.github.io/iFEM/FEM/myFiniteElement.html)
#   - [standard hp-FEM](https://jschoeberl.github.io/iFEM/pversion/myhighorder.html)
#   - [real implementation](https://github.com/NGSolve/ngsolve/blob/86bffa543e3cb5a8e7c099c17ba473ba21946bdb/fem/hcurlhofe_impl.hpp#L404)
#
# ## Element in physical coordinates:
#
#   - [Hu-Lin-Zhang element](https://github.com/JSchoeberl/Hu-Lin-Zhang-Elements)
#
# ## Elements on Alfeld splits:
#
#   - [HCT element](https://jschoeberl.github.io/iFEM/plates_shells/HCT.html) <br>
#     [Implementation](https://github.com/NGSolve/ngsolve/blob/master/comp/HCTspace.cpp)
