# %% [markdown]
# # Boundary element methods
#
# joint work with Lucy Weggler and Rafael Dorigo

# %% [markdown]
# * Extended [BEM tutorial by L. Weggler](https://weggler.github.io/docu-ngsbem/intro.html)
# * Tutorials in NGSolve docu:
#   [FEM-BEM](https://docu.ngsolve.org/latest/i-tutorials/wta/fembem.html),
#   [FMM](https://docu.ngsolve.org/latest/i-tutorials/unit-11.1-fmm/intro_fmm.html),
#   [Scattering](https://docu.ngsolve.org/latest/i-tutorials/unit-11.3-bem-Helmholtz/BrakhageWerner.html)
