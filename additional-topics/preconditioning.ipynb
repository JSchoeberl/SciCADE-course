# %% [markdown]
# # Preconditioning
#
# There are several NGSolve-tutorial dealing with using and building preconditioners
#
# ## i-tutorials: You know the theory, want to know how to implement
#   - [Schwarz methods](https://docu.ngsolve.org/latest/i-tutorials/unit-2.1.1-preconditioners/preconditioner.html)
#   - [Element-wise BDDC](https://docu.ngsolve.org/latest/i-tutorials/unit-2.1.4-bddc/bddc.html)
#   - [Auxiliary Space Preconditioning](https://docu.ngsolve.org/latest/i-tutorials/unit-2.10-dualbasis/dualbasis.html)
#
# ## i-FEM: teaching material
#
#   - [Commuting AMG](https://jschoeberl.github.io/iFEM/multigrid/amg.html)
#
# ## Treasure trove:
#
#   -  [Matrix-free high order](https://jschoeberl.github.io/treasuretrove/matrixfree/matfree-preconditioner.html)
